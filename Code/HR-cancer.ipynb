# %% [markdown]
# # HR-cancer Revision Pipeline Notebook\n\nThis notebook runs the revised end-to-end analysis for manuscript revision #93768 using the updated **Datasets** terminology and explicit single-cell multimodal handling (scRNA-seq + TCR when available).

# %%
from pathlib import Path\nimport subprocess, sys\n\nproject_root = Path.cwd().resolve().parent if Path.cwd().name == 'Code' else Path.cwd().resolve()\nprint('Project root:', project_root)

# %% [markdown]
# ## Configure input files\nSet `h5ad_path` (required) and optional metadata CSV path before running the next cell.

# %%
h5ad_path = project_root / 'Processed_Data' / 'processed_s_rna_seq_data.h5ad'  # update as needed\nmetadata_csv = project_root / 'Data' / 'GSE300475_feature_ref.csv'            # optional\nresults_dir = project_root / 'results'\nbaseline_only = True\nexclude_samples = ['S8']\nmax_pcs = 50\ntarget_variance = 0.85\nepochs = 25\nmax_trials = 8

# %%
cmd = [\n    sys.executable, str(project_root / 'run_revision_pipeline.py'),\n    '--h5ad', str(h5ad_path),\n    '--results-dir', str(results_dir),\n    '--max-pcs', str(max_pcs),\n    '--target-variance', str(target_variance),\n    '--epochs', str(epochs),\n    '--max-trials', str(max_trials),\n]\nif baseline_only:\n    cmd.append('--baseline-only')\nif metadata_csv.exists():\n    cmd += ['--metadata', str(metadata_csv)]\nif exclude_samples:\n    cmd += ['--exclude-samples', *exclude_samples]\n\nprint('Running:', ' '.join(cmd))\nsubprocess.run(cmd, check=True)

# %%
import pandas as pd\nfrom IPython.display import display\n\ndisplay(pd.read_csv(results_dir / 'patient_level_metrics.csv'))\ndisplay(pd.read_csv(results_dir / 'cell_level_metrics.csv'))
